# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Singular-Value Decomposition (SVD)
#
# Estimated time needed: **45** minutes
#
# You are a computer vision engineer and a self-driving car company has hired you.  The company would like you to remove all objects other than the street from several security videos using singular value decomposition to help test their vision system. You will use the  <a href="www.svcl.ucsd.edu/projects/background_subtraction/ucsdbgsub_dataset.html"> Background Subtraction in Dynamic dataset  </a> from the  Statistical Visual Computing Laboratory (SVCL) at UCSD.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/15104006386_1bf6bfe96a_b.jpeg" width="600">

# %% [markdown]
# ## Table of Contents
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             <li><a href="#Defining-Helper-Functions">Defining Helper Functions</a></li>
#         </ol>
#     </li>
#     <li><a href="#Singular Value Decomposition">Singular Value Decomposition</a></li>
#     <li>
#         <a href="#Truncated SVD">Truncated SVD</a>
#         <ol>
#             <li><a href="#Truncated SVD in Sklearn">Truncated SVD in Sklearn</a></li>
#             <li><a href="#Background Model using SVD">Background Model using SVD</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Exercises">Exercises</a>
#         <ol>
#             <li><a href="#Exercise 1">Exercise 1</a></li>
#             <li><a href="#Exercise 2">Exercise 2</a></li>
#             <li><a href="#Exercise 3">Exercise 3</a></li>
#             <li><a href="#Exercise 4">Exercise 4</a></li>
#             <li><a href="#Exercise 5">Exercise 5</a></li>
#         </ol>
#     </li>
#     <li><a href="#SVD from Scratch (optional)">SVD from Scratch (optional)</a></li>
#     <li><a href="#Relationship between SVD and PCA (optional)">Relationship between SVD and PCA (optional)</a></li>
#
#  </ol>

# %% [markdown]
# ***

# %% [markdown]
# ## Objectives
#
#
# *   **Understand** what is SVD in terms of Matrix Decomposition
# *   **Understand** Truncated SVD
# *   **Apply** Truncated SVD  using numpy and Sklearn
# *   **Apply** Truncated SVD  to real data
# *   **Understand** the relationship between SVD and PCA (optional)

# %% [markdown]
# ## Datasets

# %%
# !pip install -U skillsnetwork
# Out:
# Requirement already satisfied: skillsnetwork in c:\users\kymno\anaconda3\lib\site-packages (0.20.6)
# Requirement already satisfied: ipython in c:\users\kymno\anaconda3\lib\site-packages (from skillsnetwork) (8.12.0)
# Requirement already satisfied: ipywidgets<8,>=7 in c:\users\kymno\anaconda3\lib\site-packages (from skillsnetwork) (7.8.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\kymno\anaconda3\lib\site-packages (from skillsnetwork) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4 in c:\users\kymno\anaconda3\lib\site-packages (from skillsnetwork) (4.65.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\kymno\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (0.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\kymno\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\kymno\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\kymno\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\kymno\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork) (1.1.7)
# Requirement already satisfied: backcall in c:\users\kymno\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: decorator in c:\users\kymno\anaconda3\lib\site-packages (from ipython->skillsnetwork) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\kymno\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\kymno\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\kymno\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\kymno\anaconda3\lib\site-packages (from ipython->skillsnetwork) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\kymno\anaconda3\lib\site-packages (from ipython->skillsnetwork) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\kymno\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: colorama in c:\users\kymno\anaconda3\lib\site-packages (from ipython->skillsnetwork) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kymno\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kymno\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kymno\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kymno\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork) (2023.11.17)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\kymno\anaconda3\lib\site-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\kymno\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->skillsnetwork) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\kymno\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.5.4)
# Requirement already satisfied: executing in c:\users\kymno\anaconda3\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\kymno\anaconda3\lib\site-packages (from stack-data->ipython->skillsnetwork) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\kymno\anaconda3\lib\site-packages (from stack-data->ipython->skillsnetwork) (0.2.2)
# Requirement already satisfied: jinja2 in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (23.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (7.4.9)
# Requirement already satisfied: nbformat in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (5.2.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\kymno\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.5.5)
# Requirement already satisfied: six in c:\users\kymno\anaconda3\lib\site-packages (from asttokens->stack-data->ipython->skillsnetwork) (1.16.0)
# Requirement already satisfied: entrypoints in c:\users\kymno\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kymno\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\kymno\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\kymno\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\kymno\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\kymno\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.2.2)
# Requirement already satisfied: lxml in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.12.2)
# Requirement already satisfied: bleach in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.5.13)
# Requirement already satisfied: packaging in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (23.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\kymno\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.2.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\kymno\anaconda3\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\kymno\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\kymno\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\kymno\anaconda3\lib\site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.6.7)
# Requirement already satisfied: psutil in c:\users\kymno\anaconda3\lib\site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\kymno\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\kymno\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\kymno\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\kymno\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\kymno\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kymno\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.4)
# Requirement already satisfied: webencodings in c:\users\kymno\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\kymno\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\kymno\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8,>=7->skillsnetwork) (2.21)

# %% [markdown]
# Download and unzip the datasets:

# %%
import skillsnetwork, os

path1 = "./traffic.tar.gz"
await skillsnetwork.prepare("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/data/traffic.tar.gz", path1)
path2 = "./peds.tar.gz"
await skillsnetwork.prepare("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/data/peds.tar.gz", path2)
path2 = "./boats.tar.gz"
await skillsnetwork.prepare("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/data/boats.tar.gz", path3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\kymno\Documents\GitFolders\ibm_ml_course\course4_UnsupervisedLearning\SVD.ipynb Cell 9 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> import skillsnetwork, os
#       <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> path1 = f"./traffic.tar.gz"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> await skillsnetwork.prepare("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/data/traffic.tar.gz", path1)
#       <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> path2 = Path(f"./peds.tar.gz")
#       <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> await skillsnetwork.prepare("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/data/peds.tar.gz", path2)
#
# File c:\Users\kymno\Anaconda3\Lib\site-packages\skillsnetwork\core.py:249, in prepare(url, path, verbose, overwrite)
#     246 tmp_download_file = Path(f"/tmp/{dname}-{filename}")
#     247 # Download the dataset to tmp_download_file file
#     248 # File will be overwritten if it already exists
# --> 249 await download(url, tmp_download_file, verbose=False)
#     251 # Delete extract_dir directory if it already exists
#     252 if not _is_jupyterlite():
#
# File c:\Users\kymno\Anaconda3\Lib\site-packages\skillsnetwork\core.py:186, in download(url, path, verbose, chunk_size)
#     184     if path.is_dir():
#     185         path /= filename
# --> 186 with open(path, "wb") as f:  # Will raise FileNotFoundError if invalid path
#     187     async for chunk in _get_chunks(url, chunk_size):
#     188         f.write(chunk)
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\tmp\\skills-network--8023612985766784892-traffic.tar.gz'

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for mathematical operations.
# *   [`seaborn`](https://seaborn.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for visualizing the data.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for visualizing the data.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for machine learning and machine-learning-pipeline related functions.

# %% [markdown]
# ### Installing  required libraries

# %% [markdown]
# The following required modules are pre-installed in the Skills Network Labs environment. However, if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Anaconda) you will need to install these libraries by removing the `#` sign before `!mamba` in the code cell below.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 seaborn==0.9.0 matplotlib==3.5.0 scikit-learn==0.20.1
# Note: If your environment doesn't support "!mamba install", use "!pip install pandas==1.3.4 ..."

# %% [markdown]
# Install <a href="https://www.sympy.org/en/index.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork821-2023-01-01">SymPy </a> for printing matrices

# %%
# !conda install -c anaconda sympy -y
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - anaconda
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/win-64/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/noarch/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/win-64/repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/win-64/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/win-64/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/noarch/repodata.json HTTP/1.1" 304 0

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place (here):_

# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import pandas as pd
import numpy as np 


from os import listdir,getcwd
from os.path import isfile, join
from random import randint
from PIL import Image

import seaborn as sns 
import matplotlib.pylab as plt
# %matplotlib inline

from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD


from sympy import Matrix, init_printing,Symbol
from numpy.linalg import qr,eig,inv,matrix_rank,inv,svd
init_printing()

# %% [markdown]
# ### Defining Helper functions

# %%
def get_data_Matrix (mypath="peds"):
    cwd = getcwd()

    mypath=join(cwd,mypath)
    files = [ join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith(".")==False]
    # Read image
    img = Image.open(files[0])
    I=np.array(img)
    # Output Images

    Length,Width=I.shape
   
    X=np.zeros((len(files),Length*Width))
    for i,file in enumerate(files):
        img = Image.open(file)
        I=np.array(img)
        X[i,:]=I.reshape(1,-1)
    return X,Length,Width

# %% [markdown]
# ## Singular Value Decomposition
# The Singular-Value Decomposition, or SVD for short, will decompose a real or complex $N × D$ matrix $\mathbf{X}$ of rank $r$ as follows:

# %% [markdown]
# $$\mathbf{X}= \mathbf {US V^{T}}$$

# %% [markdown]
# In many applications  $N \ge D$, but SVD can be used for any matrix $\mathbf{X}$. For example, in computer vision and image processing tasks we sometimes have $D \ge N$.

# %% [markdown]
# The matrix $\mathbf{S}$ contains the nonnegative <b>singular values</b> of $\mathbf{X}$, with diagonal entries ${\sigma _{i}}$ else $0$, the entries are ordered by importance in descending order with respect to $i$, i.e:
#
# $$\sigma _{1}>\sigma _{2},..>\sigma _{r}$$

# %% [markdown]
# The matrix $\mathbf {U}$ is $NxD$ and  has the orthornormal columns  $\mathbf{u}_{1}, ..., \mathbf{u}_{D} $ called the <b>left singular vectors</b>.
#
# The matrix $\mathbf {V}$ is $DxD$ and has the orthornormal columns $\mathbf{v}_{1}, ..., \mathbf{v}_{D}$ called the <b>right singular vectors</b>  (note  that $\mathbf{V}$ transpose, $\mathbf {V^{T}}$ is returned as output in numpy's `svd` function).

# %% [markdown]
#  SVD decomposition returns the full shape of a non-square matrix, the non colored  parts of the decomposition **N-D** terms in the matrix U are zeros, we see many of the squares are redundant.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/matrix.png" width="600" alt="full svd">

# %% [markdown]
# Consider the matrix $\mathbf{X}$:

# %%
X=np.array([[1.0,2],[2,1],[3,3]])
Matrix(X)
# Out:
# ⎡1.0  2.0⎤
# ⎢        ⎥
# ⎢2.0  1.0⎥
# ⎢        ⎥
# ⎣3.0  3.0⎦

# %% [markdown]
# We can perform SVD on any matrix in numpy by using the function `svd` from `numpy.linalg`:

# %%
U, s, VT =svd(X, full_matrices=False)

# %% [markdown]
# When $\mathbf{X}$ is a 2D array, it is factorized as $U\times np.diag(s)\times V^T$, where $U$ and $V^T$ are 2D orthogonal  matrices  and $s$ is an 1D array of $\mathbf{X}$'s singular values. When $\mathbf{X}$ is higher-dimensional (such as sparse matrices), the parameter ```full_matrices=False```, the skinny SVD is used and the zero elements are dropped. This can be summarized in the following image:

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/skinny-SVD.png" width="600" alt="skinnysvd">

# %% [markdown]
# We have the <b>left singular vectors</b> of $\mathbf{X}$:

# %%
Matrix(U)
# Out:
# ⎡-0.408248290463863   0.707106781186547 ⎤
# ⎢                                       ⎥
# ⎢-0.408248290463863  -0.707106781186548 ⎥
# ⎢                                       ⎥
# ⎣-0.816496580927726  2.4980018054066e-16⎦

# %% [markdown]
# We have the <b>singular values</b> of $\mathbf{X}$, as the output is an 1-D array we use the function ```np.diag``` to convert the output into a diagonal matrix:

# %%
S=np.diag(s)

Matrix(S)
# Out:
# ⎡5.19615242270663   0 ⎤
# ⎢                     ⎥
# ⎣       0          1.0⎦

# %% [markdown]
# Finally we have the <b>right singular vectors</b> of $\mathbf{X}$, as the output is transposed they are the rows of matrix ```VT```:

# %%
Matrix(VT)
# Out:
# ⎡-0.707106781186548  -0.707106781186547⎤
# ⎢                                      ⎥
# ⎣-0.707106781186547  0.707106781186548 ⎦

# %% [markdown]
# We can reconstruct the matrix $\mathbf{X}$:

# %%
X_=U@S@VT
X_=np.round(X_)
Matrix(X_)
# Out:
# ⎡1.0  2.0⎤
# ⎢        ⎥
# ⎢2.0  1.0⎥
# ⎢        ⎥
# ⎣3.0  3.0⎦

# %% [markdown]
# It may be more intuitive if you think of SVD reconstructing the matrix as a linear combination of $r$ rank-1 matrices and the associated singular values ($r$ is the rank of $\mathbf{X}$):

# %% [markdown]
# $$\mathbf{X}=\sum_{i=1}^{r}\sigma_i\mathbf{u}_i\mathbf{v}_i^{T}$$

# %%
X_2=s[0]*U[:,0:1]@VT[0:1,:]+s[1]*U[:,1:2]@VT[1:2,:]
Matrix(X_2)
# Out:
# ⎡1.0         2.0       ⎤
# ⎢                      ⎥
# ⎢2.0  0.999999999999999⎥
# ⎢                      ⎥
# ⎣3.0         3.0       ⎦

# %% [markdown]
# The same matrix is returned!

# %% [markdown]
# ## Truncated SVD

# %% [markdown]
# A singular value $\sigma_i$ can be thought of as a measure of redundancy of a rank-1 matrix produced by $\mathbf{u}_i\mathbf{v}_i^T$. A smaller $\sigma_i$ means the associated rank-1 matrix, which can be interpreted as one "ingredient" of $\mathbf{X}$, is of less importance in terms of the amount of variance/information it preserves.
#
#
# As the information contained by the matrix becomes less important or redundant, its corresponding singular value $\sigma_i$ approaches zero. If we just keep the most important "ingredients" of $\mathbf{X}$, we can approximate $\mathbf{X}$ by a weighted sum of $L$ rank-1 matrices where  $L<r$:

# %% [markdown]
# $$\mathbf{X}\approx\sum_{i=1}^{L}\sigma_i\mathbf{u}_i\mathbf{v}_i^{T}$$

# %% [markdown]
# Consider the following matrix, the columns are almost linearly independent:

# %%
X=np.array([[1,2],[2,4],[4,8.0001]])
Matrix(X)
# Out:
# ⎡1.0   2.0  ⎤
# ⎢           ⎥
# ⎢2.0   4.0  ⎥
# ⎢           ⎥
# ⎣4.0  8.0001⎦

# %% [markdown]
# We perform SVD:

# %%
U, s, VT =svd(X, full_matrices=False)
S=np.diag(s)
Matrix(S)
# Out:
# ⎡10.2470288381327           0         ⎤
# ⎢                                     ⎥
# ⎣       0          2.18216227635671e-5⎦

# %% [markdown]
# We see the first rank-1 matrix is almost identical to the Matrix:

# %%
X_hat=np.round(s[0]*U[:,0:1]@VT[0:1,:])
Matrix(X_hat)
# Out:
# ⎡1.0  2.0⎤
# ⎢        ⎥
# ⎢2.0  4.0⎥
# ⎢        ⎥
# ⎣4.0  8.0⎦

# %% [markdown]
# Instead of adding the rank-1 matrices, we can achieve the same result with matrix multiplications. Select the top $L$ singular values, top $L$ left and right singular vectors, we can approximate $\mathbf{X}$ by:

# %% [markdown]
# $$\mathbf{X} \approx \mathbf{U}_{:,1:L} \mathbf{S}_{1:L,1:L} \mathbf{V}_{1:L,:}^{T}$$

# %% [markdown]
# Summarized in the following image:

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/trunked_-svd.png" width="600" alt="skinnysvd">

# %% [markdown]
# We can code the values in numpy:

# %%
L=1
Xhat=U[:,:L]@S[0:L,0:L]@VT[:L,:]
Matrix(Xhat)
# Out:
# ⎡0.999992380977777  2.00000380947483⎤
# ⎢                                   ⎥
# ⎢1.99998476195556   4.00000761894966⎥
# ⎢                                   ⎥
# ⎣4.00000952368254   8.00009523820408⎦

# %% [markdown]
# We can use the singular values to determine the reconstruction error, similar to the **cumulative explained variance**, we will go into the exact relationship later. The term is given by:

# %% [markdown]
# $$C(L)=\dfrac{\sum_{i=1}^{L}\sigma_i}{\sum_{i=1}^{r}\sigma_i}$$

# %%
print(f"With {L} singular value and its corresponding singular vectors, {s[0:L]/s.sum()} variance of X is explained")
# Out:
# With 1 singular value and its corresponding singular vectors, [0.99999787] variance of X is explained

# %% [markdown]
# We can plot the **cumulative explained variance** as a function of $L$ (the number of singular values chosen).

# %%
plt.figure()
plt.plot(np.cumsum(s)/s.sum())
plt.xlabel('L')
plt.title('Cumulative explained singular value')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Truncated SVD in Sklearn

# %% [markdown]
# Truncated SVD  performs **linear  PCA**, a method of dimensionality reduction. Contrary to PCA, this estimator does not center the data before computing the singular value decomposition. This means it can work with sparse matrices efficiently. We will explore the relationship between PCA and SVD later on.
#
# Some important parameters in `sklearn.decomposition.TruncatedSVD` that are worth noting:
#
# - `n_components`: int, default=2; Desired dimensionality of output data. If algorithm=’arpack’, must be strictly less than the number of features. If algorithm=’randomized’, must be less than or equal to the number of features. The default value is useful for visualisation.
#
# - `algorithm`: {‘arpack’, ‘randomized’}, default=’randomized’; SVD solver to use. Either “arpack” for the ARPACK wrapper in SciPy (scipy.sparse.linalg.svds), or “randomized” for the randomized algorithm due to [Halko (2009)](https://arxiv.org/abs/0909.4061?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork821-2023-01-01).
#
# - `n_iter`: int, default=5; Number of iterations for randomized SVD solver. Not used by ARPACK. The default is larger than the default in [randomized_svd](https://scikit-learn.org/stable/modules/generated/sklearn.utils.extmath.randomized_svd.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork821-2023-01-01#sklearn.utils.extmath.randomized_svd) to handle sparse matrices that may have large slowly decaying spectrum.
#
# _Read more in the scikit-learn documentation of [TruncatedSVD](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork821-2023-01-01)._

# %% [markdown]
# First we create a ```TruncatedSVD``` object setting ```n_components=1``` this is analogous to ```L=1``` :

# %%
svd_ = TruncatedSVD(n_components=1, random_state=42)

# %% [markdown]
# ```fit_transform```  behaves like the projections onto the principle components

# %%
Z=svd_.fit_transform(X)
Z
# Out:
# array([[2.23606798],
#        [4.47213595],
#        [8.94436135]])

# %% [markdown]
# With `inverse_transform`, we can find the approximation of the original $X$:

# %%
Xhat=svd_.inverse_transform(Z)
Matrix(np.round(Xhat))
# Out:
# ⎡1.0  2.0⎤
# ⎢        ⎥
# ⎢2.0  4.0⎥
# ⎢        ⎥
# ⎣4.0  8.0⎦

# %% [markdown]
# ### Background Model using SVD

# %% [markdown]
# In this section you will use SVD for developing a Background Model.
#
# Background subtraction is a widely used approach to detect moving objects in a sequence of frames from static cameras. The base in this approach is detecting moving objects from the differences between the current frame and reference frame, which is often called 'Background Image' or 'Background Model'.
#
# The function ```get_data_Matrix```  will create a Design  matrix ```X``` where each row corresponds to a flattened image of a sidewalk with pedestrians recorded by a camera.
#
# ```Length``` and ```Width``` are the rectangular dimensions of the image. We will use SVD to remove the pedestrians:

# %%
X,Length,Width=get_data_Matrix(mypath="peds")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\kymno\Documents\GitFolders\ibm_ml_course\course4_UnsupervisedLearning\SVD.ipynb Cell 77 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#Y135sZmlsZQ%3D%3D?line=0'>1</a> X,Length,Width=get_data_Matrix(mypath="peds")
#
# c:\Users\kymno\Documents\GitFolders\ibm_ml_course\course4_UnsupervisedLearning\SVD.ipynb Cell 77 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#Y135sZmlsZQ%3D%3D?line=1'>2</a> cwd = getcwd()
#       <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#Y135sZmlsZQ%3D%3D?line=3'>4</a> mypath=join(cwd,mypath)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#Y135sZmlsZQ%3D%3D?line=4'>5</a> files = [ join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith(".")==False]
#       <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#Y135sZmlsZQ%3D%3D?line=5'>6</a> # Read image
#       <a href='vscode-notebook-cell:/c%3A/Users/kymno/Documents/GitFolders/ibm_ml_course/course4_UnsupervisedLearning/SVD.ipynb#Y135sZmlsZQ%3D%3D?line=6'>7</a> img = Image.open(files[0])
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'c:\\Users\\kymno\\Documents\\GitFolders\\ibm_ml_course\\course4_UnsupervisedLearning\\peds'

# %% [markdown]
# There are 170 images in the dataset and each is $152\times 232$ (32654 pixels).

# %%
X.shape, Length, Width

# %% [markdown]
# We can plot five random images from the matrix:

# %%
for i in range(5):
    frame=randint(0, X.shape[0]-1)
    plt.imshow(X[randint(0, X.shape[0]-1),:].reshape(Length,Width),cmap="gray")
    plt.title("frame: "+str(frame))
    plt.show()

# %% [markdown]
# We perform SVD on the images:

# %%
U, s, VT =svd(X, full_matrices=False)

# %%
S=np.diag(s)

# %% [markdown]
# We can reconstruct the image using Truncated SVD with ```L=1``` and assign the result to to ```Xhat```:

# %%
L=1
Xhat=U[:,:L]@S[0:L,0:L]@VT[:L,:]

# %% [markdown]
# If we plot the first image, we will see the pedestrians are gone:

# %%
plt.imshow(Xhat[0,:].reshape(Length,Width),cmap="gray")
plt.title('Truncated SVD L=1')
plt.show()

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1
#
# Reshape the 5 random rows of ```Xhat``` and plot them as images.

# %%
# TODO

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# for i in range(5):
#     frame=randint(0, X.shape[0]-1)
#     plt.imshow(Xhat[randint(0, X.shape[0]-1),:].reshape(Length,Width),cmap="gray")
#     plt.title("frame: "+str(frame))
#     plt.show()
# ```
#
# </details>

# %% [markdown]
# From the exercise above that the rows of the matrix ```Xhat``` are all similar . The ```L``` determines the reconstruction properties.

# %% [markdown]
# ### Exercise 2
#
# Plot the Cumulative explained variance against the number of singular values $L$.

# %%
#TODO

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# plt.plot(np.cumsum(s)/s.sum())
# plt.xlabel('L')
# plt.title('Cumulative explained  singular value')
# plt.show()
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3
# Perform Truncated SVD with ```L=10``` and plot 5 random rows of Xhat.

# %%
#TODO

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# L=10
# Xhat=U[:,:L]@S[0:L,0:L]@VT[:L,:]
# for i in range(5):
#     frame=randint(0, X.shape[0]-1)
#     plt.imshow(Xhat[randint(0, X.shape[0]-1),:].reshape(Length,Width),cmap="gray")
#     plt.title("frame: "+str(frame))
#     plt.show()
# ```
# </details>

# %% [markdown]
# ### Exercise 4
#  Apply   ```get_data_Matrix``` with ```mypath="boats"```, plot 5 random boat images. Then perform Truncated SVD using the function ```svd``` with  L=1 and plot the first row of ```Xhat``` as an image.

# %%
#TODO

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# X,Length,Width=get_data_Matrix (mypath="boats")
#
# for i in range(5):
#     frame=randint(0, X.shape[0]-1)
#     plt.imshow(X[randint(0, X.shape[0]-1),:].reshape(Length,Width),cmap="gray")
#     plt.title("frame: "+str(frame))
#     plt.show()
#
# U, s, VT =svd(X, full_matrices=False)
# L=1
# Xhat=U[:,:L]@S[0:L,0:L]@VT[:L,:]
#
# plt.imshow(Xhat[0,:].reshape(Length,Width),cmap="gray")
# plt.title('Truncated SVD L=1')
#
# plt.show()
# ```
#
# </details>

# %% [markdown]
# ### Exercise 5
# Apply   ```get_data_Matrix``` with ```mypath="traffic"```, plot 5 random images. Then perform Truncated SVD  using `TruncatedSVD` with ```n_components=1``` and plot the first row of ```Xhat``` as an image.

# %%
#TODO

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# X,Length,Width=get_data_Matrix (mypath="traffic")
#
# for i in range(5):
#     frame=randint(0, X.shape[0]-1)
#     plt.imshow(X[randint(0, X.shape[0]-1),:].reshape(Length,Width),cmap="gray")
#     plt.title("frame: "+str(frame))
#     plt.show()
#
# svd_ = TruncatedSVD(n_components=1, n_iter=7, random_state=42)
# score=svd_.fit_transform(X)
# Xhat=svd_.inverse_transform(score)
# plt.imshow(Xhat[0,:].reshape(Length,Width),cmap="gray")
# plt.imshow(Xhat[0,:].reshape(Length,Width),cmap="gray")
# plt.title('Truncated SVD L=1')
#
# plt.show()
# plt.show()
#
# ```
#
# </details>

# %% [markdown]
# ##  SVD from Scratch (optional)

# %% [markdown]
# There are several ways to derive SVD, let's do one that is simple to code and related to PCA. We have the SVD factorization:

# %% [markdown]
# $$\mathbf{X}= \mathbf {US V^{T}}$$

# %%
X=np.array([[1,2],[2,4],[4,8]])
Matrix(X)

# %% [markdown]
# From the last section you recall that $DxD$  matrix $\mathbf{C}$   is a symmetric matrix, this is almost  the same matrix used in PCA if we can scale the covariance matrix by $N$ and obtain the eigenvalues and eigenvectors (eigenvectors have unit norm so multiplying constant will not effect them):

# %% [markdown]
# $$\mathbf{C'}=\mathbf{X}^T \mathbf{X}=\mathbf{V}\mathbf{\Lambda}\mathbf{V}^{T}$$

# %% [markdown]
# The $\mathbf{V}$ is the same as the right singular vectors, in Python we can evaluate ```V``` as follows:

# %%
C=X.T@X
eigen_vectors1 , V=eig(C)
Matrix(V)

# %% [markdown]
# We can also perform the same decomposition with the Gram matrix:

# %% [markdown]
# $G=\mathbf{X} \mathbf{X}^T= \mathbf{U \Lambda U^{T}}$

# %% [markdown]
# Where $\mathbf{U}$ are the the right singular vectors

# %%
G=X@X.T
eigen_vectors2 , U=eig(G)
Matrix(U)

# %% [markdown]
# There are several way to obtains the singular values as we know  $\mathbf{X}= \mathbf {USV^{T}}$. With some algebra we know that $\mathbf{S}=\mathbf{U^TXV}$

# %%
S=np.round((U.T@X@V))
Matrix(S)

# %% [markdown]
# Singular values are not in descending order, and the shape difference is because this is not the economy-size decomposition.
# Now that we have all the components, we can reconstruct the matrix:

# %%
X_=np.round(U@S@V.T)
Matrix(X_)

# %% [markdown]
# ## Relationship between SVD and PCA (optional)

# %% [markdown]
# In the section above we derived SVD. Let's use this to better understand how SVD and PCA are almost the same. Let's use the following dateset:

# %%
N=200
u=np.array([[1.0,1.0],[0.10,-0.10]])/(2)**(0.5)
X_=np.dot(4*np.random.randn(N,2),u)+10
X=X_-X_.mean(axis=0)

# %% [markdown]
# Let's compare SVD to sklearn's PCA  setting ```n_components=1```

# %%
U, s, VT =svd(X, full_matrices=False)

# %%
pca = PCA(n_components=1)
projection=pca.fit_transform(X)
X_sklearn=pca.inverse_transform(projection)

# %% [markdown]
# As $\mathbf{V}$ are the principal components, the projections on the principal components can be found by multiplying $\mathbf{X}$ and $\mathbf{V}$, if we want the projection on the first principal components, we can take the row of $\mathbf{V}$ with the largest Singular-Value Value and compare it to scikit-learn's. We see the result is identical:

# %%
projection_=X@VT[0,:]
print ("error SVD vs scikit-learn's PCA",(projection_-projection).sum())

# %% [markdown]
# We can also find the projections using  $\mathbf{XV}= \mathbf {US}$. Here we find the projection on the first principal component to compare to scikit-learn's

# %%
projection_=U@np.diag(s)[:,0]
print ("error SVD vs scikit-learn's PCA",(projection_-projection).sum())

# %% [markdown]
# The inverse transform on the first  principal component is simply the low rank approximation:

# %%
L=1
Xhat=U[:,:L]@np.diag(s[0:L])@VT[:L,:] # resconstruct X
print ("error SVD vs scikit-learn's PCA",((Xhat-X_sklearn)**2).sum())

# %% [markdown]
# The relationship between the explained variance and singular  values are given by  $\lambda_i = s_i^2/(N-1)$ we can verify the for the first singular value:

# %%
s[0]**2/(200-1)

# %%
pca.explained_variance_

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2021-01-01">Joseph Santarcangelo</a> has a Ph.D. in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# [Roxanne Li](https://www.linkedin.com/in/roxanne-li/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork821-2023-01-01) is a Data Science intern at IBM Skills Network, entering level-5 study in the Mathematics & Statistics undergraduate Coop program at McMaster University.

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By  | Change Description             |
# | ----------------- | ------- | ----------- | ------------------------------ |
# | 2022-03-25        | 0.1     | Joseph S.   | Updated all content            |
# | 2022-04-26        | 0.1     | Svitlana K. | Corrected minor grammar errors |
# | 2022-05-26        | 0.1     | Roxanne Li  | Review and edit content    |
# | 2022-06-02        | 0.2     | Steve H.    | QA pass     |
