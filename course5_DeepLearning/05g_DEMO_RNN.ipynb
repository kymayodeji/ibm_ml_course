# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Machine Learning Foundation
#
# ## Course 5, Part g: RNN DEMO

# %% [markdown]
# ## Using RNNs to classify sentiment on IMDB data
# For this exercise, we will train a "vanilla" RNN to predict the sentiment on IMDB reviews.  Our data consists of 25000 training sequences and 25000 test sequences.  The outcome is binary (positive/negative) and both outcomes are equally represented in both the training and the test set.
#
# Keras provides a convenient interface to load the data and immediately encode the words into integers (based on the most common words).  This will save us a lot of the drudgery that is usually involved when working with raw text.
#
# We will walk through the preparation of the data and the building of an RNN model.  Then it will be your turn to build your own models (and prepare the data how you see fit).

# %%
# %%capture
# !pip install --upgrade tensorflow

# %%
from tensorflow import keras
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import SimpleRNN
from keras.datasets import imdb
from keras import initializers
# Out:
# WARNING:tensorflow:From c:\Users\kymno\Anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
max_features = 20000  # This is used in loading the data, picks the most common (max_features) words
maxlen = 30  # maximum length of a sequence - truncate after this
batch_size = 32

# %%
## Load in the data.  The function automatically tokenizes the text into distinct integers
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')
# Out:
# 25000 train sequences
# 25000 test sequences

# %%
# This pads (or truncates) the sequences so that they are of the maximum length
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (25000, 30)
# x_test shape: (25000, 30)

# %%
x_train[123,:]  #Here's what an example sequence looks like
# Out:
# array([  219,   141,    35,   221,   956,    54,    13,    16,    11,
#         2714,    61,   322,   423,    12,    38,    76,    59,  1803,
#           72,     8, 10508,    23,     5,   967,    12,    38,    85,
#           62,   358,    99])

# %% [markdown]
# ## Keras layers for (Vanilla) RNNs
#
# In this exercise, we will not use pre-trained word vectors.  Rather we will learn an embedding as part of the Neural Network.  This is represented by the Embedding Layer below.
#
# ### Embedding Layer
# `keras.layers.embeddings.Embedding(input_dim, output_dim, embeddings_initializer='uniform', embeddings_regularizer=None, activity_regularizer=None, embeddings_constraint=None, mask_zero=False, input_length=None)`
#
# - This layer maps each integer into a distinct (dense) word vector of length `output_dim`.
# - Can think of this as learning a word vector embedding "on the fly" rather than using an existing mapping (like GloVe)
# - The `input_dim` should be the size of the vocabulary.
# - The `input_length` specifies the length of the sequences that the network expects.
#
# ### SimpleRNN Layer
# `keras.layers.recurrent.SimpleRNN(units, activation='tanh', use_bias=True, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros', kernel_regularizer=None, recurrent_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, recurrent_constraint=None, bias_constraint=None, dropout=0.0, recurrent_dropout=0.0)`
#
# - This is the basic RNN, where the output is also fed back as the "hidden state" to the next iteration.
# - The parameter `units` gives the dimensionality of the output (and therefore the hidden state).  Note that typically there will be another layer after the RNN mapping the (RNN) output to the network output.  So we should think of this value as the desired dimensionality of the hidden state and not necessarily the desired output of the network.
# - Recall that there are two sets of weights, one for the "recurrent" phase and the other for the "kernel" phase.  These can be configured separately in terms of their initialization, regularization, etc.

# %%
## Let's build a RNN

rnn_hidden_dim = 5
word_embedding_dim = 50
model_rnn = Sequential()
model_rnn.add(Embedding(max_features, word_embedding_dim))  #This layer takes each integer in the sequence and embeds it in a 50-dimensional vector
model_rnn.add(SimpleRNN(rnn_hidden_dim,
                    kernel_initializer=initializers.RandomNormal(stddev=0.001),
                    recurrent_initializer=initializers.Identity(gain=1.0),
                    activation='relu',
                    input_shape=x_train.shape[1:]))

model_rnn.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From c:\Users\kymno\Anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
## Note that most of the parameters come from the embedding layer
model_rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 50)          1000000
#
#  simple_rnn (SimpleRNN)      (None, 5)                 280
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 1000286 (3.82 MB)
# Trainable params: 1000286 (3.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = .0001)

model_rnn.compile(loss='binary_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])

# %%
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\kymno\Anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\kymno\Anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 782/782 [==============================] - 14s 15ms/step - loss: 0.6787 - accuracy: 0.5737 - val_loss: 0.6496 - val_accuracy: 0.6520
# Epoch 2/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.6092 - accuracy: 0.6813 - val_loss: 0.5878 - val_accuracy: 0.6929
# Epoch 3/10
# 782/782 [==============================] - 11s 14ms/step - loss: 0.5412 - accuracy: 0.7332 - val_loss: 0.5420 - val_accuracy: 0.7242
# Epoch 4/10
# 782/782 [==============================] - 11s 14ms/step - loss: 0.4936 - accuracy: 0.7647 - val_loss: 0.5190 - val_accuracy: 0.7401
# Epoch 5/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.4597 - accuracy: 0.7848 - val_loss: 0.4973 - val_accuracy: 0.7549
# Epoch 6/10
# 782/782 [==============================] - 11s 14ms/step - loss: 0.4343 - accuracy: 0.7993 - val_loss: 0.4833 - val_accuracy: 0.7633
# Epoch 7/10
# 782/782 [==============================] - 11s 14ms/step - loss: 0.4139 - accuracy: 0.8132 - val_loss: 0.4723 - val_accuracy: 0.7710
# Epoch 8/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.3984 - accuracy: 0.8210 - val_loss: 0.4639 - val_accuracy: 0.7767
# Epoch 9/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.3851 - accuracy: 0.8280 - val_loss: 0.4615 - val_accuracy: 0.7795
# Epoch 10/10
# 782/782 [==============================] - 10s 13ms/step - loss: 0.3747 - accuracy: 0.8347 - val_loss: 0.4574 - val_accuracy: 0.7838

# %%
score, acc = model_rnn.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 782/782 [==============================] - 3s 3ms/step - loss: 0.4574 - accuracy: 0.7838
# Test score: 0.4573918879032135
# Test accuracy: 0.7838000059127808

# %% [markdown]
# ## Exercise
#
# In this exercise, we will illustrate:
# - Preparing the data to use sequences of length 80 rather than length 50.  Does it improve the performance?
# - Trying different values of the "max_features".  Does this  improve the performance?
# - Trying smaller and larger sizes of the RNN hidden dimension.  How does it affect the model performance?  How does it affect the run time?

# %%
max_features = 20000  # This is used in loading the data, picks the most common (max_features) words
maxlen = 80  # maximum length of a sequence - truncate after this

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %%
rnn_hidden_dim = 5
word_embedding_dim = 50
model_rnn = Sequential()
model_rnn.add(Embedding(max_features, word_embedding_dim))  #This layer takes each integer in the sequence
model_rnn.add(SimpleRNN(rnn_hidden_dim,
                    kernel_initializer=initializers.RandomNormal(stddev=0.001),
                    recurrent_initializer=initializers.Identity(gain=1.0),
                    activation='relu',
                    input_shape=x_train.shape[1:]))

model_rnn.add(Dense(1, activation='sigmoid'))

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = .0001)

model_rnn.compile(loss='binary_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])

# %%
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 19s 22ms/step - loss: 0.6594 - accuracy: 0.6051 - val_loss: 0.6029 - val_accuracy: 0.6750
# Epoch 2/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.5206 - accuracy: 0.7498 - val_loss: 0.5127 - val_accuracy: 0.7503
# Epoch 3/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.4382 - accuracy: 0.8015 - val_loss: 0.4595 - val_accuracy: 0.7787
# Epoch 4/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.3884 - accuracy: 0.8302 - val_loss: 0.4318 - val_accuracy: 0.7968
# Epoch 5/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.3522 - accuracy: 0.8491 - val_loss: 0.4254 - val_accuracy: 0.8046
# Epoch 6/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.3271 - accuracy: 0.8618 - val_loss: 0.4165 - val_accuracy: 0.8107
# Epoch 7/10
# 782/782 [==============================] - 18s 22ms/step - loss: 0.3086 - accuracy: 0.8696 - val_loss: 0.3968 - val_accuracy: 0.8192
# Epoch 8/10
# 782/782 [==============================] - 18s 24ms/step - loss: 0.2921 - accuracy: 0.8786 - val_loss: 0.3990 - val_accuracy: 0.8194
# Epoch 9/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.2786 - accuracy: 0.8876 - val_loss: 0.3837 - val_accuracy: 0.8308
# Epoch 10/10
# 782/782 [==============================] - 18s 23ms/step - loss: 0.2679 - accuracy: 0.8906 - val_loss: 0.3724 - val_accuracy: 0.8351

# %% [markdown]
# Lets alter max_features from 10,000 to 5000 while keeping the maxlen at 80 as the previous model performed better than the model where the maxlen was 50.

# %%
max_features = 5000  # This is used in loading the data, picks the most common (max_features) words
maxlen = 80  # maximum length of a sequence - truncate after this

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# %%
rnn_hidden_dim = 5
word_embedding_dim = 20
model_rnn = Sequential()
model_rnn.add(Embedding(max_features, word_embedding_dim))  #This layer takes each integer in the sequence
model_rnn.add(SimpleRNN(rnn_hidden_dim,
                    kernel_initializer=initializers.RandomNormal(stddev=0.001),
                    recurrent_initializer=initializers.Identity(gain=1.0),
                    activation='relu',
                    input_shape=x_train.shape[1:]))

model_rnn.add(Dense(1, activation='sigmoid'))

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = .0001)

model_rnn.compile(loss='binary_crossentropy',
              optimizer=rmsprop,
              metrics=['accuracy'])

# %%
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 19s 22ms/step - loss: 0.6824 - accuracy: 0.5384 - val_loss: 0.6545 - val_accuracy: 0.5818
# Epoch 2/10
# 782/782 [==============================] - 16s 21ms/step - loss: 0.6223 - accuracy: 0.6944 - val_loss: 0.6029 - val_accuracy: 0.7406
# Epoch 3/10
# 782/782 [==============================] - 15s 20ms/step - loss: 0.5805 - accuracy: 0.7622 - val_loss: 0.5788 - val_accuracy: 0.7865
# Epoch 4/10
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5545 - accuracy: 0.7884 - val_loss: 0.5641 - val_accuracy: 0.7871
# Epoch 5/10
# 782/782 [==============================] - 17s 21ms/step - loss: 0.5361 - accuracy: 0.8058 - val_loss: 0.5679 - val_accuracy: 0.7686
# Epoch 6/10
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5209 - accuracy: 0.8166 - val_loss: 0.5516 - val_accuracy: 0.7844
# Epoch 7/10
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5076 - accuracy: 0.8235 - val_loss: 0.5307 - val_accuracy: 0.8052
# Epoch 8/10
# 782/782 [==============================] - 18s 23ms/step - loss: 0.4881 - accuracy: 0.8252 - val_loss: 0.4811 - val_accuracy: 0.7878
# Epoch 9/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.4063 - accuracy: 0.8199 - val_loss: 0.4439 - val_accuracy: 0.7882
# Epoch 10/10
# 782/782 [==============================] - 16s 21ms/step - loss: 0.3807 - accuracy: 0.8321 - val_loss: 0.4431 - val_accuracy: 0.7885

# %% [markdown]
# Decreasing the maxfeatures from 10,000 to 5,000 didn't perform as well with the same number of epocs. Lets double the number of epochs to see if that has an effect?

# %%
# Out of curiosity, run for 10 more epochs
model_rnn.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 16s 21ms/step - loss: 0.3652 - accuracy: 0.8437 - val_loss: 0.4184 - val_accuracy: 0.8130
# Epoch 2/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.3542 - accuracy: 0.8473 - val_loss: 0.4084 - val_accuracy: 0.8139
# Epoch 3/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.3456 - accuracy: 0.8527 - val_loss: 0.4000 - val_accuracy: 0.8207
# Epoch 4/10
# 782/782 [==============================] - 17s 21ms/step - loss: 0.3385 - accuracy: 0.8563 - val_loss: 0.4209 - val_accuracy: 0.8134
# Epoch 5/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.3316 - accuracy: 0.8582 - val_loss: 0.3841 - val_accuracy: 0.8290
# Epoch 6/10
# 782/782 [==============================] - 17s 22ms/step - loss: 0.3257 - accuracy: 0.8620 - val_loss: 0.3848 - val_accuracy: 0.8292
# Epoch 7/10
# 782/782 [==============================] - 15s 19ms/step - loss: 0.3203 - accuracy: 0.8656 - val_loss: 0.3867 - val_accuracy: 0.8288
# Epoch 8/10
# 782/782 [==============================] - 15s 19ms/step - loss: 0.3150 - accuracy: 0.8690 - val_loss: 0.3859 - val_accuracy: 0.8242
# Epoch 9/10
# 782/782 [==============================] - 17s 21ms/step - loss: 0.3106 - accuracy: 0.8702 - val_loss: 0.3792 - val_accuracy: 0.8317
# Epoch 10/10
# 782/782 [==============================] - 18s 22ms/step - loss: 0.3063 - accuracy: 0.8720 - val_loss: 0.3804 - val_accuracy: 0.8301

# %% [markdown]
# ---
# ### Machine Learning Foundation (C) 2020 IBM Corporation
